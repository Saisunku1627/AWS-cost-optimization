# %% [markdown]
# ## Assignment for Week 6 - K-Means and Hierarchical Clustering
#
# ### Exerise:
# #### KMeans and Hierarchial Clustering
#
# Collect data from Reddit (at least 1000 posts). You may scrape data from a specific subreddit or the 'All' front page.
# To gather your Reddit data I would recommend using the python library [PRAW](https://praw.readthedocs.io/en/stable/).  There is addition information and instructions in the worldclass assignment folder.<br>
#
# - Scrape, properly clean and prepare the Reddit data (2pts)
# - Use PCA to reduce the dimensions Include a scree plot and explain how many components you retained and why (2pts)
# - Apply K-Means and HCA to cluster the PCA (2 pts)
# - Identify number of optimum clusters, and justify how do you picked the optimum number of clusters (1 pts)
# - Visually present clusters in an informative manner (1 pts)
# - Summarize your findings.  Be sure to include insights in the clusters or grouping of the post types. For example, do different clusters tend to have different themes, sentiment, common words, etc. (2 pts)
# - *Bonus:* Compare TF-IDF vs. [BERT embeddings](https://sbert.net). Which worked better for your clustering and why? (1 pts)

# %% [markdown]
# ### Deliverables:
#
# Upload your notebook's .ipynb file.
#
# **Important:** Make sure your provide complete and thorough explanations for all of your analysis. You need to defend your thought processes and reasoning.

# %%
# Some code to get you started scraping Reddit
import praw
reddit = praw.Reddit(client_id='',
                     client_secret='',
                     user_agent='', 
                     username='', 
                     password='')
