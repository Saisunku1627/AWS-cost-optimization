# %% [markdown]
# ## Assignment for Week 1 - Introduction to Machine Learning
#
# We will use the heart.disease.data file, which has 15 attributes and 1 target variable.  Prepare the data for machine learning tasks use in later weeks.
# **Dataset**
# - UCI Riverside Heart Disease dataset, which has 15 attributes and 1 target variable
# - http://archive.ics.uci.edu/ml/datasets/heart+Disease (Use the data sourced in the Week 1 Content folder)
#
#
# **Objective:** Prepare the real-world dataset for machine learning.
#
# **Goals:**
# - Conduct meaningful exploratory data analysis (EDA)
# - Drop unnecessary columns and deal with outliers (if needed), and justify your decision to do so in a markdown cell
# - Impute missing data and justify how and why you imputed the data in a markdown cell.
# - Provide a brief summary of how you prepared your data for future analysis in a markdown cell.
#
# **Deliverables:**
# Upload your completed notebook .ipynb file

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Heart_df=pd.read_csv('/Users/saitejasunku/Downloads/heart.disease.data.csv')

# %%
Heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  cigs  years  fbs  dm  famhist  restecg  \
# 0   29    1   2       130   204     2      6    0   1        0        2
# 1   34    1   1       118   182    20      6    0  -9        0        2
# 2   34    0   2       118   210    10     15    0  -9        1        0
# 3   35    0   4       138   183     0      0    0  -9        1        0
# 4   35    1   4       120   198     0      0    0  -9        0        0
#
#    thalach  exang  thal  slope  num
# 0      202      0     3      1    0
# 1      174      0     3      1    0
# 2      192      0     3      1    0
# 3      182      0     3      1    0
# 4      130      1     7      2    1

# %%
Heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       282 non-null    int64
#  1   sex       282 non-null    int64
#  2   cp        282 non-null    int64
#  3   trestbps  282 non-null    int64
#  4   chol      282 non-null    int64
#  5   cigs      282 non-null    int64
#  6   years     282 non-null    int64
#  7   fbs       282 non-null    int64
#  8   dm        282 non-null    int64
#  9   famhist   282 non-null    int64
#  10  restecg   282 non-null    int64
#  11  thalach   282 non-null    int64
#  12  exang     282 non-null    int64
#  13  thal      282 non-null    int64
#  14  slope     282 non-null    int64
#  15  num       282 non-null    int64
# dtypes: int64(16)
# memory usage: 35.4 KB

# %%
print(df['dm'].value_counts())
Heart_df.isna().sum()
# Out:
# dm
# -9    259
#  1     23
# Name: count, dtype: int64
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# cigs        0
# years       0
# fbs         0
# dm          0
# famhist     0
# restecg     0
# thalach     0
# exang       0
# thal        0
# slope       0
# num         0
# dtype: int64

# %% [markdown]
# # dtatset details

# %% [markdown]
# 1. age,
# Description: Age of the patient in years.
#
# 2. sex,
# Description: Gender of the patient.
#
# 3. cp (Chest Pain Type),
# Description: Type of chest pain experienced by the patient.
#
# 4. trestbps (Resting Blood Pressure),
# Description: Resting blood pressure in mmHg (millimeters of mercury).
#
# 5. chol (Cholesterol),
# Description: Serum cholesterol level in mg/dL (milligrams per deciliter).
#
#
# 6. cigs (Cigarettes Smoked per Day),
# Description: Number of cigarettes smoked per day.
#
#
# 7. years (Years Smoked),
# Description: Number of years the patient has been smoking.
#
#
# 8. fbs (Fasting Blood Sugar),
# Description: Fasting blood sugar level.
#
#
# 9. dm (Diabetes Mellitus),
# Description: Presence of diabetes mellitus.
#
#
# 10. famhist (Family History of Heart Disease),
# Description: Family history of heart disease.
#
#
# 11. restecg (Resting Electrocardiographic Results),
# Description: Resting electrocardiographic results.
#
#
# 12. thalach (Maximum Heart Rate Achieved),
# Description: Maximum heart rate achieved during exercise.
#
#
# 13. exang (Exercise-Induced Angina),
# Description: Presence of exercise-induced angina.
#
#
# 14. thal (Thalassemia),
# Description: Type of thalassemia.
#
#
# 15. num (Target Variable),
# Description: Diagnosis of heart disease.

# %% [markdown]
# # replacing null values

# %%
Heart_df.replace(-9, np.nan,inplace=True)

# %%
Heart_df.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      0
# chol          0
# cigs          5
# years         5
# fbs           0
# dm          259
# famhist       0
# restecg       0
# thalach       0
# exang         0
# thal          2
# slope         0
# num           0
# dtype: int64

# %%
Heart_df.describe()
# Out:
#               age         sex          cp    trestbps        chol        cigs  \
# count  282.000000  282.000000  282.000000  282.000000  282.000000  277.000000
# mean    54.411348    0.677305    3.163121  131.563830  249.092199   16.920578
# std      9.053083    0.468338    0.955405   17.757496   51.217546   19.451934
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  213.000000    0.000000
# 50%     55.000000    1.000000    3.000000  130.000000  244.000000   10.000000
# 75%     61.000000    1.000000    4.000000  140.000000  277.000000   30.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000   99.000000
#
#             years         fbs    dm     famhist     restecg     thalach  \
# count  277.000000  282.000000  23.0  282.000000  282.000000  282.000000
# mean    15.259928    0.148936   1.0    0.620567    1.014184  149.765957
# ...

# %% [markdown]
# # Handelling missing data

# %%
Heart_df.isnull().sum()/len(df)
# Out:
# age         0.000000
# sex         0.000000
# cp          0.000000
# trestbps    0.000000
# chol        0.000000
# cigs        0.017730
# years       0.017730
# fbs         0.000000
# dm          0.918440
# famhist     0.000000
# restecg     0.000000
# thalach     0.000000
# exang       0.000000
# thal        0.007092
# slope       0.000000
# num         0.000000
# dtype: float64

# %% [markdown]
# dm column: 259 out of 282 values are missing (92%). This column is almost entirely empty and may not be useful for analysis.So i will drop this column

# %%
Heart_df.drop("dm",axis=1,inplace=True)

# %%
print(Heart_df['cigs'].skew())
print(Heart_df['years'].skew())
print(Heart_df['thal'].skew())
# Out:
# 1.1313201489368827
# 0.4214964884051561
# 0.30642936349359323

# %% [markdown]
# 'cigs', 'years', and 'thal' columns are right skewed.The median is less sensitive to outliers than the mean. In right-skewed distributions, outliers tend to be on the higher end, which can significantly influence the mean. By using the median, we can mitigate the impact of these outliers on the imputation.
# Reference:https://online.stat.psu.edu/stat200/lesson/2/2.2/2.2.4/2.2.4.1

# %% [markdown]
# Imputation of Missing Values                                                     Using their median values, we filled in the blanks in the columns **cigs**, **years**, and **thal**.
#  By using the median rather than the mean, the data distribution remains constant and the impact of outliers is lessened.

# %%
for col in ['cigs', 'years', 'thal']:
    median_val = Heart_df[col].median()
    Heart_df[col] = Heart_df[col].fillna(median_val)

# %%
Heart_df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# cigs        0
# years       0
# fbs         0
# famhist     0
# restecg     0
# thalach     0
# exang       0
# thal        0
# slope       0
# num         0
# dtype: int64

# %% [markdown]
# # EDA

# %%
Heart_df.hist(figsize=(12, 8))
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(Heart_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
sns.pairplot(Heart_df)
plt.show()

# %% [markdown]
# Positive correlations:
#
# cigs and years (0.64):
#
# This indicates that there is a substantial positive correlation between the number of years smoked (years) and the number of cigarettes smoked per day (cigs).   This is to be expected since those who smoke more cigarettes per day are likely to have been smokers for a longer amount of time.
#  Num and thal (0.50):
#
#  This suggests a somewhat positive relationship between num (heart disease diagnosis) and thal (thalassemia).  greater num values are correlated with greater thal values.
#
# exang and num (0.40):
#
# This suggests that num and exang (exercise-induced angina) have a moderately positive connection.  Heart disease is more likely to occur in those who have exercise-induced angina.
#
# cp and num (0.38):
#
# This suggests that num and cp (type of chest pain) have a moderately favorable connection.  Heart disease is linked to specific forms of chest pain.
#
# thal and exang (0.33):
#
# This suggests that thal and exang have a somewhat positive association.  Exercise-induced angina is more common in patients with specific forms of thalassemia.
#
# sex and num (0.24):
#
# This suggests that there is a marginally positive association between heart disease and sex.  Heart disease is somewhat more common in men (encoded as 1).
#
#
#
# Negative correlation:
#
# thalach and num (-0.40):
#
# This indicates a moderate negative correlation between thalach (maximum heart rate achieved) and num.  An increased risk of heart disease is linked to lower maximal heart rates.
#
# thalach and exang (-0.37):
#
# This suggests that thalach and exang have a somewhat negative connection.  Angina brought on by exercise is linked to lower maximal heart rates.
#
# age and num (-0.21):
#
# This suggests that cardiac disease and age have a weakly negative association.  Heart disease is marginally less common in older persons.

# %%
print(Heart_df["famhist"].value_counts())
# Out:
# famhist
# 1    175
# 0    107
# Name: count, dtype: int64

# %%
print(Heart_df["fbs"].value_counts())
# Out:
# fbs
# 0    240
# 1     42
# Name: count, dtype: int64

# %% [markdown]
# # outlier analysis

# %%
plt.figure(figsize=(12, 8))
for i, col in enumerate(df.columns, 1):
    plt.subplot(4, 4, i)
    sns.boxplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# # handelling outliers using iqr method

# %%
k=["cp", "trestbps", "chol","cigs","thalach"]

# %%
for col in Heart_df.columns:
    Q1 = Heart_df[col].quantile(0.25)
    Q3 = Heart_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    Heart_df[col] = df[col].clip(lower_bound, upper_bound)

# %%
plt.figure(figsize=(12, 8))
for i, col in enumerate(k, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# Since these are more likely to be impacted by extreme values, I concentrated on columns that are continuous numerical variables and have a larger range of values when dealing with outliers.  Cp (kind of chest pain), trestbps (resting blood pressure), chol (cholesterol), cigs (number of cigarettes smoked daily), and thalach (highest heart rate attained) are the columns in which I specifically used the IQR approach to cap outliers.  Because they show a wider range of values and are more prone to outliers that could distort the study, these columns were selected.  However, since the fbs (fasting blood sugar) column is a binary feature with only two potential values (0 and 1), I did not apply outlier treatment to it because it is less likely to be affected by ouliers.

# %%
X = Heart_df.drop("num", axis=1)  
y = Heart_df["num"]

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()


X_scaled = scaler.fit_transform(X)


X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %% [markdown]
# # summary

# %% [markdown]
# To make sure the dataset was clean, consistent, and prepared for analysis, it went through a thorough pretreatment routine.  To make handling easier, missing values denoted by -9 were first changed to NaN.  Because of the large percentage of missing values (92%) that rendered the dm column unsuitable for analysis, it was eliminated.  The median for numerical columns was used to impute missing values in the cigs, years, and thal columns.  This method preserved the integrity of the dataset while guaranteeing that no important data was lost.
#
# In order to comprehend the structure of the dataset and spot any possible problems, exploratory data analysis, or EDA, was then carried out.  Each feature's distribution was examined using histograms and boxplots, which showed skewness and outliers in number columns including age, trestbps, chol, and thalach.  A heatmap was also created to look at the connections between the features.  Strong correlations between some variables were shown in the heatmap, including the positive connection between cp (kind of chest pain) and num and the negative correlation with thalach (highest heart rate) and num (goal variable).  To further understand the structure of the data, a pair plot was also made to show pairwise correlations between numerical features.
#
# Using the IQR (Interquartile Range) approach, outliers in numerical columns (cp, trestbps, chol, cigs, and thalach) were addressed.  By capping extreme values, this technique preserves genuine data points while preventing distortion of the study.  Since the fbs column is a binary feature with just two potential values (0 and 1), it is less vulnerable to outliers and was not treated for them.
#
# Lastly, StandardScaler was used to standardize numerical features using feature scaling.  By transforming the data into a mean of 0 and a standard deviation of 1, standardization guarantees that every characteristic makes an equal contribution to the analysis.  This stage is essential for enhancing the efficiency of machine learning algorithms, especially those that use gradient-based optimization or distance computations.
#
# Now that all features have been appropriately scaled and are free of outliers, the final dataset is clean and prepared for machine learning modeling.  For the sake of maintaining its original distribution, the target variable (num) was not scaled.  This thorough preprocessing method guarantees that the dataset is reliable and appropriate for precise modeling and analysis.
